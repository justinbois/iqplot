# %% [markdown]
# # Test plots

# %%
import numpy as np
import pandas as pd

import iqplot

import bokeh.sampledata.autompg

import bokeh.io
bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ec353aa7-daaa-44e7-a82a-ffe7afc913ab">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Some data for test plots, the MPG data set and a generated data set with two categories.

# %%
df = bokeh.sampledata.autompg.autompg_clean

np.random.seed(3252)

df_pc = pd.DataFrame(
    np.vstack(
        (
            np.random.normal(5, 1, size=39),
            np.random.normal(4, 1, size=39),
            np.random.normal(6, 1, size=39),
        )
    ).transpose(),
    columns=["control", "exp 1", "exp 2"],
)
df_pc["day"] = ["Mon"] * 14 + ["Tues"] * 10 + ["Wed"] * 15
df_pc["trial"] = np.arange(1, len(df_pc) + 1)

# Melt to make it in iqplot's format
df_pc = df_pc.melt(id_vars=['day', 'trial'], var_name="exp", value_name='val')

# %%
p = iqplot.box(data=df, q="mpg", cats="origin", title="box")
bokeh.io.show(p)
# Out:
#   <div id="be12f9b4-a4df-49e3-958e-17635cbfae45" data-root-id="p1002" style="display: contents;"></div>

# %%
p = iqplot.box(data=df, q="mpg", cats="origin", q_axis='y')
bokeh.io.show(p)
# Out:
#   <div id="b63440cf-c694-40df-adde-b1b13a1ff0f4" data-root-id="p1264" style="display: contents;"></div>

# %%
p = iqplot.box(data=df, q="mpg", cats=["origin", 'cyl'], q_axis='y')
bokeh.io.show(p)
# Out:
#   <div id="d73624e0-45d7-4414-8694-5ccaa3580c03" data-root-id="p1558" style="display: contents;"></div>

# %%
p = iqplot.box(data=df, q="mpg", cats=["origin", 'cyl'], min_data=4)
bokeh.io.show(p)
# Out:
#   <div id="b1aaf96e-7c3b-41e1-a344-1ef147081860" data-root-id="p1880" style="display: contents;"></div>

# %%
p = iqplot.box(data=df, q="mpg", cats="origin", order=['North America', 'Asia', 'Europe'])
bokeh.io.show(p)
# Out:
#   <div id="c6162b81-8fac-46de-90f6-580b374fb53b" data-root-id="p2230" style="display: contents;"></div>

# %%
p = iqplot.box(data=df, q="mpg", cats=["cyl", "origin"], min_data=4)
bokeh.io.show(p)
# Out:
#   <div id="d029a20b-57f3-48d9-9795-57fd399cc576" data-root-id="p2608" style="display: contents;"></div>

# %%
p = iqplot.box(data=df, q="mpg", cats=["cyl", "origin"], cat_grid=True)
bokeh.io.show(p)
# Out:
#   <div id="ced291d0-378a-4b1a-b9f8-55e4c07eab5c" data-root-id="p3014" style="display: contents;"></div>

# %%
p = iqplot.strip(data=df, q="mpg", cats="origin", title="strip")
bokeh.io.show(p)
# Out:
#   <div id="d52bdb44-7c8f-48af-a2f2-9dab8692d202" data-root-id="p3448" style="display: contents;"></div>

# %%
p = iqplot.stripbox(data=df, q="mpg", cats="origin", title="strip-box")
bokeh.io.show(p)
# Out:
#   <div id="a2c1cfac-e70c-401d-ac01-a9753ac93302" data-root-id="p3781" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(data=df, q="mpg", cats="origin", title="strip-histogram")
bokeh.io.show(p)
# Out:
#   <div id="f53e41bb-4833-4faf-8e08-1ffcc4707d53" data-root-id="p4311" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(data=df, q="mpg", cats="origin", q_axis='y')
bokeh.io.show(p)
# Out:
#   <div id="c10f536d-74cb-4fb1-ba02-7cfc88205516" data-root-id="p4949" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(data=df, q="mpg", cats="origin", q_axis='y', conf_int=True, ptiles=[14, 86])
bokeh.io.show(p)
# Out:
#   <div id="d47133ad-7e62-405e-a138-c16f2d671f3a" data-root-id="p5635" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(data=df, q="mpg", cats="origin", q_axis='y', spread='jitter', conf_int=True, ptiles=[14, 86])
bokeh.io.show(p)
# Out:
#   <div id="ca6f8573-2a42-4caa-82a5-2313e559861f" data-root-id="p6488" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(data=df, q="mpg", cats="origin", q_axis='y', spread='swarm', conf_int=True, ptiles=[14, 86])
bokeh.io.show(p)
# Out:
# /Users/bois/Dropbox/git/iqplot/iqplot/cat.py:1769: UserWarning: 2 data points exceed maximum width. Consider using spread='jitter' or increasing the frame width.
#   warnings.warn(
#   <div id="a2ec6bf9-7b48-4662-a86f-8d490aba620b" data-root-id="p7401" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(data=df, q="mpg", cats="origin", q_axis='y', spread='jitter', conf_int=True, color_column='cyl', ptiles=[14, 86])
bokeh.io.show(p)
# Out:
#   <div id="b7961234-34fd-44ac-b0e8-20ff77cf7f27" data-root-id="p8372" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(
    data=df, q="mpg", cats="origin", q_axis='y', spread='jitter', conf_int=True, color_column='cyl', ptiles=[14, 86],
    tooltips=[('year', '@yr')]
)
bokeh.io.show(p)
# Out:
#   <div id="e170972f-b11d-4a11-b3f1-c03bdf64da3b" data-root-id="p9585" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(
    data=df, q="mpg", cats="origin", q_axis='y', spread='jitter', color_column='cyl',
    tooltips=[('year', '@yr')]
)
bokeh.io.show(p)
# Out:
#   <div id="b9419284-a6e1-4c96-81c6-7cc36ad10324" data-root-id="p10884" style="display: contents;"></div>

# %%
p = iqplot.histogram(data=df, q="mpg", cats="origin", title="histogram")
bokeh.io.show(p)
# Out:
#   <div id="e9fafc43-054f-451b-b51e-461fa22ab9c9" data-root-id="p12139" style="display: contents;"></div>

# %%
p = iqplot.histogram(data=df, q="mpg", cats="origin", mirror=True, tooltips=[('year', '@yr')])
bokeh.io.show(p)
# Out:
#   <div id="e0379e94-3753-40b5-bd0b-103d3b2e09bc" data-root-id="p13668" style="display: contents;"></div>

# %%
p = iqplot.ecdf(data=df, q="mpg", cats="origin", title="ecdf")
bokeh.io.show(p)
# Out:
#   <div id="a46daa5f-5983-4007-a5cd-3d2a16f80520" data-root-id="p15286" style="display: contents;"></div>

# %%
p = iqplot.ecdf(data=df, q="mpg", cats="origin", arrangement='stack', tooltips=[('year', '@yr')], style='staircase', title='ECDF')
bokeh.io.show(p)
# Out:
#   <div id="c9567d4d-90d8-4e08-ab21-4d3ea3c30b18" data-root-id="p16792" style="display: contents;"></div>

# %%
p = iqplot.ecdf(data=df, q="mpg", cats="origin", arrangement='stack', tooltips=[('year', '@yr')], style='staircase', conf_int=True,)
bokeh.io.show(p)
# Out:
#   <div id="b01c70c9-5004-4be5-9281-c309dcff13c0" data-root-id="p18658" style="display: contents;"></div>

# %%
p = iqplot.ecdf(data=df, q="mpg", cats="origin", arrangement='overlay', tooltips=[('year', '@yr')], style='staircase', conf_int=True,)
bokeh.io.show(p)
# Out:
#   <div id="ea5608e5-0144-4a41-9fad-5ffb0081cbd1" data-root-id="p20306" style="display: contents;"></div>

# %%
p = iqplot.strip(
    df_pc,
    q="val",
    cats=["day", "exp"],
    q_axis="y",
    frame_width=500,
    color_column="exp",
    parcoord_column="trial",
)

bokeh.io.show(p)
# Out:
#   <div id="e79396de-9210-47af-a101-35958de27df5" data-root-id="p22158" style="display: contents;"></div>

# %%
p = iqplot.stripbox(
    df_pc,
    q="val",
    cats=["day", "exp"],
    q_axis="y",
    frame_width=500,
    color_column="exp",
    parcoord_column="trial",
)

bokeh.io.show(p)
# Out:
#   <div id="f2c2e838-1a33-4691-b250-3d43c03d0fe5" data-root-id="p23619" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(
    df_pc,
    q="val",
    cats=["day", "exp"],
    q_axis="y",
    frame_width=500,
    color_column="exp",
    parcoord_column="trial",
)

bokeh.io.show(p)
# Out:
#   <div id="fab6036c-25c7-4fcc-8ef0-096204105e32" data-root-id="p25201" style="display: contents;"></div>

# %%
p = iqplot.strip(df, 'mpg', spread='swarm', tooltips=[('cyl', '@cyl')], q_axis='x')
bokeh.io.show(p)
# Out:
#   <div id="a2d5dac6-5fc0-40fc-a6ef-0f1661a24d00" data-root-id="p27505" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(
    df_pc,
    q="val",
    cats=["day", "exp"],
    q_axis="y",
    frame_width=500,
    color_column="exp",
    spread='jitter',
    parcoord_column="trial",
)

bokeh.io.show(p)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 p = iqplot.striphistogram(
#       2     df_pc,
#       3     q="val",
#       4     cats=["day", "exp"],
#       5     q_axis="y",
#       6     frame_width=500,
#       7     color_column="exp",
#       8     spread='jitter',
#       9     parcoord_column="trial",
#      10 )
#      12 bokeh.io.show(p)
#
# File ~/Dropbox/git/iqplot/iqplot/cat.py:1365, in striphistogram(data, q, cats, q_axis, palette, order, p, show_legend, legend_location, legend_orientation, legend_click_policy, top_level, color_column, parcoord_column, tooltips, marker, spread, cat_grid, marker_kwargs, jitter_kwargs, swarm_kwargs, parcoord_kwargs, bins, style, mirror, hist_height, conf_int, ptiles, n_bs_reps, line_kwargs, fill_kwargs, conf_int_kwargs, kind, jitter, horizontal, val, click_policy, **kwargs)
#    1338 elif top_level == "strip":
#    1339     p = histogram(
#    1340         data=data,
#    1341         q=q,
#    (...)
#    1362         **kwargs,
#    1363     )
# -> 1365     p = strip(
#    1366         data=data,
#    1367         q=q,
#    1368         cats=cats,
#    1369         q_axis=q_axis,
#    1370         palette=palette,
#    1371         order=order,
#    1372         p=p,
#    1373         cat_grid=cat_grid,
#    1374         show_legend=show_legend,
#    1375         color_column=color_column,
#    1376         parcoord_column=parcoord_column,
#    1377         tooltips=tooltips,
#    1378         marker=marker,
#    1379         spread=spread,
#    1380         marker_kwargs=marker_kwargs,
#    1381         jitter_kwargs=jitter_kwargs,
#    1382         swarm_kwargs=swarm_kwargs,
#    1383         parcoord_kwargs=parcoord_kwargs,
#    1384         jitter=jitter,
#    1385         horizontal=horizontal,
#    1386         val=val,
#    1387     )
#    1389     if not cat_grid:
#    1390         p.xgrid.grid_line_color = None
#
# File ~/Dropbox/git/iqplot/iqplot/cat.py:189, in strip(data, q, cats, q_axis, palette, order, p, show_legend, legend_location, legend_orientation, legend_click_policy, color_column, parcoord_column, tooltips, marker, spread, cat_grid, marker_kwargs, jitter_kwargs, swarm_kwargs, parcoord_kwargs, jitter, horizontal, val, click_policy, **kwargs)
#     186             warnings.warn("`jitter` is deprecated. Use spread='jitter'.")
#     188 if spread is not None and spread != "none" and parcoord_column is not None:
# --> 189     raise NotImplementedError(
#     190         "Parallel coordinate plots are not implemented with jitter or swarm spreading."
#     191     )
#     193 if palette is None:
#     194     palette = colorcet.b_glasbey_category10
#
# NotImplementedError: Parallel coordinate plots are not implemented with jitter or swarm spreading.
