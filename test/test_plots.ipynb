# %% [markdown]
# # Test plots

# %%
import numpy as np
import pandas as pd

import iqplot

import bokeh.sampledata.autompg

import bokeh.io
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a9831dde-85b9-4a72-9d46-aca122f8b33d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Some data for test plots, the MPG data set and a generated data set with two categories.

# %%
df = bokeh.sampledata.autompg.autompg_clean

np.random.seed(3252)

df_pc = pd.DataFrame(
    np.vstack(
        (
            np.random.normal(5, 1, size=39),
            np.random.normal(4, 1, size=39),
            np.random.normal(6, 1, size=39),
        )
    ).transpose(),
    columns=["control", "exp 1", "exp 2"],
)
df_pc["day"] = ["Mon"] * 14 + ["Tues"] * 10 + ["Wed"] * 15
df_pc["trial"] = np.arange(1, len(df_pc) + 1)

# Melt to make it in iqplot's format
df_pc = df_pc.melt(id_vars=['day', 'trial'], var_name="exp", value_name='val')

# %%
p = iqplot.box(data=df, q="mpg", cats="origin", title="box")
bokeh.io.show(p)
# Out:
#   <div id="a62cd2a7-f258-429e-83bf-dce6ae1c90b8" data-root-id="p1002" style="display: contents;"></div>

# %%
p = iqplot.box(data=df, q="mpg", cats="origin", q_axis='y')
bokeh.io.show(p)
# Out:
#   <div id="ad341a9b-43ee-4cf4-9b1a-4c94e6962530" data-root-id="p1090" style="display: contents;"></div>

# %%
p = iqplot.box(data=df, q="mpg", cats=["origin", 'cyl'], q_axis='y')
bokeh.io.show(p)
# Out:
#   <div id="c8dd8ccb-befd-4f5b-af64-f7b1f0389025" data-root-id="p1177" style="display: contents;"></div>

# %%
p = iqplot.box(data=df, q="mpg", cats=["origin", 'cyl'], min_data=4)
bokeh.io.show(p)
# Out:
#   <div id="f730f54b-d0de-4450-9b2d-992bb8f41259" data-root-id="p1264" style="display: contents;"></div>

# %%
p = iqplot.box(data=df, q="mpg", cats="origin", order=['North America', 'Asia', 'Europe'])
bokeh.io.show(p)
# Out:
#   <div id="ed7e8db0-db01-4aa7-96af-62f5c214eaa7" data-root-id="p1351" style="display: contents;"></div>

# %%
p = iqplot.box(data=df, q="mpg", cats=["cyl", "origin"], min_data=4)
bokeh.io.show(p)
# Out:
#   <div id="aacfae2c-4ed6-4eb0-9e2d-b1201c788108" data-root-id="p1438" style="display: contents;"></div>

# %%
p = iqplot.box(data=df, q="mpg", cats=["cyl", "origin"], cat_grid=True)
bokeh.io.show(p)
# Out:
#   <div id="a918ac2c-a049-4230-8c82-e40e4d2fb26d" data-root-id="p1525" style="display: contents;"></div>

# %%
p = iqplot.strip(data=df, q="mpg", cats="origin", title="strip")
bokeh.io.show(p)
# Out:
#   <div id="a6e68cd9-cf2a-4a07-aa4f-5164b8270176" data-root-id="p1612" style="display: contents;"></div>

# %%
p = iqplot.stripbox(data=df, q="mpg", cats="origin", title="strip-box")
bokeh.io.show(p)
# Out:
#   <div id="eadf4017-c9f8-4a36-b4fe-2e971437ec53" data-root-id="p1660" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(data=df, q="mpg", cats="origin", title="strip-histogram")
bokeh.io.show(p)
# Out:
#   <div id="e0f1d23f-6d78-439f-a054-d6baf2997850" data-root-id="p1772" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(data=df, q="mpg", cats="origin", q_axis='y')
bokeh.io.show(p)
# Out:
#   <div id="b9a51174-b012-4dd0-ad5f-aae4415da480" data-root-id="p1881" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(data=df, q="mpg", cats="origin", q_axis='y', conf_int=True, ptiles=[14, 86])
bokeh.io.show(p)
# Out:
#   <div id="d5f6615a-034e-4038-ac4c-cd1e8a981ff8" data-root-id="p1989" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(data=df, q="mpg", cats="origin", q_axis='y', spread='jitter', conf_int=True, ptiles=[14, 86])
bokeh.io.show(p)
# Out:
#   <div id="bc25e5a0-169a-4696-ad15-7ae3866824bf" data-root-id="p2121" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(data=df, q="mpg", cats="origin", q_axis='y', spread='swarm', conf_int=True, ptiles=[14, 86])
bokeh.io.show(p)
# Out:
# /Users/bois/Dropbox/git/iqplot/iqplot/cat.py:1804: UserWarning: 2 data points exceed maximum width. Consider using spread='jitter' or increasing the frame width.
#   warnings.warn(
#   <div id="e7812f41-bb10-4bf3-a56c-f14f26df23eb" data-root-id="p2254" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(data=df, q="mpg", cats="origin", q_axis='y', spread='jitter', conf_int=True, color_column='cyl', ptiles=[14, 86])
bokeh.io.show(p)
# Out:
#   <div id="f80d35fb-cf5f-4e1c-bc77-f0a466273210" data-root-id="p2386" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(
    data=df, q="mpg", cats="origin", q_axis='y', spread='jitter', conf_int=True, color_column='cyl', ptiles=[14, 86],
    tooltips=[('year', '@yr')]
)
bokeh.io.show(p)
# Out:
#   <div id="ce008f86-d8ff-4e40-91e5-7f857fae073f" data-root-id="p2581" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(
    data=df, q="mpg", cats="origin", q_axis='y', spread='jitter', color_column='cyl',
    tooltips=[('year', '@yr')]
)
bokeh.io.show(p)
# Out:
#   <div id="de39ef35-bc53-416c-80cb-d7abf1db4466" data-root-id="p2782" style="display: contents;"></div>

# %%
p = iqplot.histogram(data=df, q="mpg", cats="origin", title="histogram")
bokeh.io.show(p)
# Out:
#   <div id="f00dbb3e-cab4-4247-8e99-1fe80ca6f0ff" data-root-id="p2959" style="display: contents;"></div>

# %%
p = iqplot.histogram(data=df, q="mpg", cats="origin", mirror=True, tooltips=[('year', '@yr')])
bokeh.io.show(p)
# Out:
#   <div id="f28ccd08-cef3-4d5e-bb26-85239868f4e8" data-root-id="p3233" style="display: contents;"></div>

# %%
p = iqplot.ecdf(data=df, q="mpg", cats="origin", title="ecdf")
bokeh.io.show(p)
# Out:
#   <div id="a59d9e87-cbd6-430b-8878-ffb79252bf14" data-root-id="p3506" style="display: contents;"></div>

# %%
p = iqplot.ecdf(data=df, q="mpg", cats="origin", arrangement='stack', tooltips=[('year', '@yr')], style='staircase', title='ECDF')
bokeh.io.show(p)
# Out:
#   <div id="f4f6d63d-d1cd-40b5-8d58-21826c368341" data-root-id="p3855" style="display: contents;"></div>

# %%
p = iqplot.ecdf(data=df, q="mpg", cats="origin", arrangement='stack', tooltips=[('year', '@yr')], style='staircase', conf_int=True,)
bokeh.io.show(p)
# Out:
#   <div id="d50e77b5-2ea2-40f6-9ced-bf687109c7e7" data-root-id="p4141" style="display: contents;"></div>

# %%
p = iqplot.ecdf(data=df, q="mpg", cats="origin", arrangement='overlay', tooltips=[('year', '@yr')], style='staircase', conf_int=True,)
bokeh.io.show(p)
# Out:
#   <div id="b2065d20-c5ad-4935-8403-fed4f7084cf3" data-root-id="p4176" style="display: contents;"></div>

# %%
p = iqplot.strip(
    df_pc,
    q="val",
    cats=["day", "exp"],
    q_axis="y",
    frame_width=500,
    color_column="exp",
    parcoord_column="trial",
)

bokeh.io.show(p)
# Out:
#   <div id="d9ccd2d7-beda-40d4-b319-04d4e076088a" data-root-id="p4391" style="display: contents;"></div>

# %%
p = iqplot.stripbox(
    df_pc,
    q="val",
    cats=["day", "exp"],
    q_axis="y",
    frame_width=500,
    color_column="exp",
    parcoord_column="trial",
)

bokeh.io.show(p)
# Out:
#   <div id="c9394c8e-528d-435b-850d-de79c8963662" data-root-id="p4482" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(
    df_pc,
    q="val",
    cats=["day", "exp"],
    q_axis="y",
    frame_width=500,
    color_column="exp",
    parcoord_column="trial",
)

bokeh.io.show(p)
# Out:
#   <div id="a3eab5b6-ad66-4d2c-b224-624c56d25815" data-root-id="p4605" style="display: contents;"></div>

# %%
p = iqplot.strip(df, 'mpg', spread='swarm', tooltips=[('cyl', '@cyl')], q_axis='x')
bokeh.io.show(p)
# Out:
#   <div id="ba0742ea-0681-4005-aa27-3559c856d865" data-root-id="p4877" style="display: contents;"></div>

# %%
p = iqplot.striphistogram(
    df_pc,
    q="val",
    cats=["day", "exp"],
    q_axis="y",
    frame_width=500,
    color_column="exp",
    spread='jitter',
    parcoord_column="trial",
)

bokeh.io.show(p)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 p = iqplot.striphistogram(
#       2     df_pc,
#       3     q="val",
#       4     cats=["day", "exp"],
#       5     q_axis="y",
#       6     frame_width=500,
#       7     color_column="exp",
#       8     spread='jitter',
#       9     parcoord_column="trial",
#      10 )
#      12 bokeh.io.show(p)
#
# File ~/Dropbox/git/iqplot/iqplot/cat.py:1394, in striphistogram(data, q, cats, q_axis, palette, order, p, show_legend, legend_location, legend_orientation, legend_click_policy, top_level, color_column, parcoord_column, tooltips, marker, spread, cat_grid, marker_kwargs, jitter_kwargs, swarm_kwargs, parcoord_kwargs, bins, style, mirror, hist_height, conf_int, ptiles, n_bs_reps, line_kwargs, fill_kwargs, conf_int_kwargs, kind, jitter, horizontal, val, click_policy, **kwargs)
#    1367 elif top_level == "strip":
#    1368     p = histogram(
#    1369         data=data,
#    1370         q=q,
#    (...)
#    1391         **kwargs,
#    1392     )
# -> 1394     p = strip(
#    1395         data=data,
#    1396         q=q,
#    1397         cats=cats,
#    1398         q_axis=q_axis,
#    1399         palette=palette,
#    1400         order=order,
#    1401         p=p,
#    1402         cat_grid=cat_grid,
#    1403         show_legend=show_legend,
#    1404         color_column=color_column,
#    1405         parcoord_column=parcoord_column,
#    1406         tooltips=tooltips,
#    1407         marker=marker,
#    1408         spread=spread,
#    1409         marker_kwargs=marker_kwargs,
#    1410         jitter_kwargs=jitter_kwargs,
#    1411         swarm_kwargs=swarm_kwargs,
#    1412         parcoord_kwargs=parcoord_kwargs,
#    1413         jitter=jitter,
#    1414         horizontal=horizontal,
#    1415         val=val,
#    1416     )
#    1418     if not cat_grid:
#    1419         p.xgrid.grid_line_color = None
#
# File ~/Dropbox/git/iqplot/iqplot/cat.py:199, in strip(data, q, cats, q_axis, palette, order, p, show_legend, legend_location, legend_orientation, legend_click_policy, color_column, parcoord_column, tooltips, marker, spread, cat_grid, marker_kwargs, jitter_kwargs, swarm_kwargs, parcoord_kwargs, jitter, horizontal, val, click_policy, **kwargs)
#     194     raise RuntimeError(
#     195         "Invalid `spread`. Valid choices are 'swarm', 'jitter', and None."
#     196         )
#     198 if spread is not None and spread != "none" and parcoord_column is not None:
# --> 199     raise NotImplementedError(
#     200         "Parallel coordinate plots are not implemented with jitter or swarm spreading."
#     201     )
#     203 if palette is None:
#     204     palette = colorcet.b_glasbey_category10
#
# NotImplementedError: Parallel coordinate plots are not implemented with jitter or swarm spreading.
